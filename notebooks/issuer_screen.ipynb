# %% [markdown]
# # Issuer Screen — 3D Credit Idea Engine
# This notebook runs the CLI and previews the generated scorecards.

# %%
import os, sys, pathlib
from credit3d.cli import main
print('Run from shell: !python -m credit3d.cli --data_dir ./data --horizon_months 6 --funding_rate 0.02 --mandate protection')
